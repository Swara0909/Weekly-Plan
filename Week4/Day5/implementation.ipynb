# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization
import matplotlib.pyplot as plt

# Load dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize
x_train = x_train / 255.0
x_test = x_test / 255.0

# Model
model = Sequential([
    # Flatten(input_shape=(28,28)),

    # Dense(128, activation='relu'),

    # BatchNormalization(),

    # Dense(64, activation='relu'),

    # BatchNormalization(),

    # Dense(10, activation='softmax')

        Flatten(input_shape=(28,28)),

    Dense(
        128,
        activation='relu',
        kernel_initializer='he_uniform'
    ),

    Dense(
        64,
        activation='relu',
        kernel_initializer='he_uniform'
    ),

    Dense(10, activation='softmax')
    
])

# Compile
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train
history = model.fit(
    x_train,
    y_train,
    epochs=5,
    validation_data=(x_test, y_test)
)

# Evaluate
loss, accuracy = model.evaluate(x_test, y_test)

print("Accuracy:", accuracy)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9295 - loss: 0.2398 - val_accuracy: 0.9612 - val_loss: 0.1246
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9696 - loss: 0.0999 - val_accuracy: 0.9704 - val_loss: 0.0942
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9785 - loss: 0.0687 - val_accuracy: 0.9771 - val_loss: 0.0744
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9826 - loss: 0.0527 - val_accuracy: 0.9765 - val_loss: 0.0732
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9865 - loss: 0.0410 - val_accuracy: 0.9764 - val_loss: 0.0828
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - accuracy: 0.9764 - loss: 0.0828
# Accuracy: 0.9764000177383423
